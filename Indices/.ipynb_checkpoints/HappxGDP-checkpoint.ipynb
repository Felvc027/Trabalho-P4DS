# %%
import scipy as sp
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.formula.api as sm

# %%
feli = pd.read_excel('World_Happiness_Report_2017.xls', sheet_name='Figure2.2 WHR 2017')["Happiness score"]
gdp = pd.read_excel("GDP_per_capita.xls", sheet_name='Data', header=3)[["Country Name", "2017"]]
from Fnames import names
feli.index, gdp.index = names, gdp["Country Name"]
feli = pd.DataFrame(feli.reindex(gdp["Country Name"]))
comp = feli.join(gdp["2017"]).dropna()
comp
# Out:
#                           Happiness score          2017
# Country Name
# Afghanistan                         3.794    585.850064
# Angola                              3.795   4170.312280
# Albania                             4.644   4537.862492
# United Arab Emirates                6.993  40698.849336
# Argentina                           6.599  14401.974855
# Armenia                             4.376   3936.798320
# Australia                           7.284  53799.938090
# Austria                             7.006  47290.911650
# Azerbaijan                          5.234   4131.618310
# Burundi                             2.905    320.086870
# Belgium                             6.891  43323.807336
# Benin                               3.657    829.797231
# Burkina Faso                        4.032    670.705913
# Bangladesh                          4.608   1516.513423
# Bulgaria                            4.714   8031.598442
# Bahrain                             6.087  23655.035602
# Bosnia and Herzegovina              5.182   5180.636301
# Belarus                             5.569   5726.029673
# Belize                              5.956   4905.506284
# Bolivia                             5.823   3393.955818
# Brazil                              6.635   9821.407686
# Bhutan                              5.011   3110.230113
# Botswana                            3.766   7595.595850
# Central African Republic            2.693    418.411287
# Canada                              7.316  45032.119908
# Switzerland                         7.494  80189.696861
# Chile                               6.652  15346.449700
# China                               6.422   8826.994096
# Cote d'Ivoire                       4.180   1662.442467
# Cameroon                            4.695   1446.702895
# ...                                   ...           ...
# Saudi Arabia                        6.344  20760.906012
# Sudan                               4.139   2898.549346
# Senegal                             4.535   1033.069906
# Singapore                           6.572  57714.296631
# Sierra Leone                        4.709    499.426295
# El Salvador                         6.003   3889.308769
# Somalia                             5.151    499.816802
# Serbia                              5.395   5900.038108
# Slovak Republic                     6.098  17604.950977
# Slovenia                            5.758  23597.291726
# Sweden                              7.284  53442.008281
# Chad                                3.936    669.886426
# Togo                                3.495    617.176610
# Thailand                            6.424   6593.819806
# Tajikistan                          5.041    800.966964
# Turkmenistan                        5.822   7355.831345
# South Asia (IDA & IBRD)             3.591   1840.616372
# Trinidad and Tobago                 6.168  16145.184573
# Tunisia                             4.805   3490.828293
# Turkey                              5.500  10540.617999
# Tanzania                            3.349    936.330768
# Uganda                              4.081    604.042748
# Ukraine                             4.096   2639.824326
# Uruguay                             6.454  16245.598368
# United States                       6.648  59531.661964
# Uzbekistan                          5.971   1504.226546
# Vietnam                             5.074   2343.124575
# Kosovo                              5.279   3893.969824
# Zambia                              4.514   1509.797013
# Zimbabwe                            3.875   1079.608291
#
# [150 rows x 2 columns]

# %%
plt.scatter(comp["2017"] ,comp["Happiness score"])
plt.ylim(2.5,8.5)
plt.xlim(-10000, 100000)
plt.show()

# %%
comp.columns = ["y","x"]
reg = sm.ols(formula='y~x', data=comp).fit()
reg.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.470
# Model:                            OLS   Adj. R-squared:                  0.467
# Method:                 Least Squares   F-statistic:                     131.5
# Date:                Wed, 26 Sep 2018   Prob (F-statistic):           3.53e-22
# Time:                        12:52:47   Log-Likelihood:                -181.39
# No. Observations:                 150   AIC:                             366.8
# Df Residuals:                     148   BIC:                             372.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      4.8226      0.082     58.841      0.000       4.661       4.985
# x           3.761e-05   3.28e-06     11.466      0.000    3.11e-05    4.41e-05
# ==============================================================================
# Omnibus:                        4.335   Durbin-Watson:                   2.021
# Prob(Omnibus):                  0.114   Jarque-Bera (JB):                4.220
# Skew:                          -0.411   Prob(JB):                        0.121
# Kurtosis:                       2.969   Cond. No.                     3.07e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.07e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
comp.columns = ["y","x"]
plt.scatter(y=comp['y'], x=comp['x'], color='blue', s=50, alpha=.5)
X_plot = sp.linspace(min(comp['x']), max(comp['x']), len(comp['x']))
plt.plot(X_plot, X_plot*reg.params[1] + reg.params[0], color='r')
plt.ylim(2.5,8.5)
plt.xlim(-10000, 100000)
plt.title('Linha de tendencia')
plt.xlabel("GDP per capita")
plt.ylabel("Happiness score")
plt.show()
