# %%
from analyze import analise

# %%
analise(2017)
# Out:
#                                                     High-technology exports  \
# Country
# Aruba                                                                   NaN
# Afghanistan                                                             NaN
# Angola                                                                  NaN
# Albania                                                                 NaN
# Andorra                                                                 NaN
# Arab World                                                              NaN
# United Arab Emirates                                                    NaN
# Argentina                                                               NaN
# Armenia                                                                 NaN
# American Samoa                                                          NaN
# Antigua and Barbuda                                                     NaN
# ...

# %%
analise(2017, 'Ease of doing business index', True, "plot")
# Out:
# Intercept                      107073.400562
# pow(x, 0.15000000000000002)    -48996.027209
# dtype: float64
# r**2: 0.41475560108763854
# Country: 183
